# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp("The Reel Sisters is about a group of four (recently became five) unique girls who are initially brought together by fly fishing but now alMelody is the newcomer, the youngest, and a photographer by passion, who joins the group through an unusual incident.")
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# The DET det
# Reel PROPN compound
# Sisters PROPN nsubj
# is AUX ccomp
# about ADP prep
# a DET det
# group NOUN pobj
# of ADP prep
# four NUM pobj
# ( PUNCT punct
# recently ADV advmod
# became VERB ROOT
# five NUM attr
# ) PUNCT punct
# unique ADJ amod
# girls NOUN ROOT
# who PRON nsubjpass
# are AUX auxpass
# initially ADV advmod
# brought VERB relcl
# together ADV advmod
# by ADP agent
# fly VERB compound
# fishing VERB pobj
# but CCONJ cc
# now ADV advmod
# also ADV advmod
# have AUX conj
# an DET det
# incredible ADJ amod
# friendship NOUN dobj
# . PUNCT punct
# They PRON nsubj
# are AUX ROOT
# quite ADV advmod
# similar ADJ acomp
# when ADV advmod
# it PRON nsubj
# comes VERB advcl
# to ADP prep
# kindness NOUN pobj
# and CCONJ cc
# making VERB conj
# wisecracks NOUN dobj
# . PUNCT punct
# The DET det
# lives NOUN nsubj
# they PRON nsubj
# lead VERB relcl
# are AUX ROOT
# quite ADV advmod
# different ADJ acomp
# . PUNCT punct
# No ADV neg
# matter ADV advmod
# what PRON nsubj
# ...
